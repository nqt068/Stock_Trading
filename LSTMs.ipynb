# %%
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from keras.layers import Dense, SimpleRNN
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasClassifier, KerasRegressor

# %% [markdown]
# # Load data from yahoo finance

# %% [markdown]
# The yf.download function from the yfinance library is used to retrieve the historical data for the S&P 500 index.
#
# ^GSPC is the ticker symbol for the S&P 500 index.
#
# The start parameter specifies the start date for the data retrieval (January 1, 2010, in this case).
#
# The end parameter specifies the end date for the data retrieval (April 10, 2020, in this case).
#
# The retrieved data is stored in a DataFrame called df.

# %%
df = yf.download("^GSPC", start="2010-01-01", end="2020-04-10")     #^GSPC is the annotation for stock S&P500
df.reset_index(drop = True, inplace = True)
#Drop columns
df.drop(["Adj Close", "Volume"], axis = 1, inplace = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#              Open         High          Low        Close
# 0     1116.560059  1133.869995  1116.560059  1132.989990
# 1     1132.660034  1136.630005  1129.660034  1136.520020
# 2     1135.709961  1139.189941  1133.949951  1137.140015
# 3     1136.270020  1142.459961  1131.319946  1141.689941
# 4     1140.520020  1145.390015  1136.219971  1144.979980
# ...           ...          ...          ...          ...
# 2580  2514.919922  2538.179932  2459.959961  2488.649902
# 2581  2578.280029  2676.850098  2574.570068  2663.679932
# 2582  2738.649902  2756.889893  2657.669922  2659.409912
# 2583  2685.000000  2760.750000  2663.300049  2749.979980
# 2584  2776.989990  2818.570068  2762.360107  2789.820068
#
# [2585 rows x 4 columns]

# %% [markdown]
# ## Create input

# %% [markdown]
# In Keras, the input shape for an LSTM (Long Short-Term Memory) layer depends on the format of your data.
# The LSTM layer expects input in the form of a 3D tensor with shape (batch_size, timesteps, input_dim).
#
# +Batch_size: The number of samples in each batch. This dimension is typically left unspecified or set to None in the input shape, allowing for variable batch sizes during training and inference.
#
# +Timesteps: The number of time steps or sequences in your input data. For example, if you have a time series of length 100, and you want to consider 20 previous time steps as input for each sample, then timesteps would be 20.
#
# +Input_dim: The number of features or dimensions in each time step of your input data.

# %%
#Sequence Creation Function for Time Series Data
def create_sequences(data: pd.DataFrame, seq_length: int):
    X = []
    y = []
    for i in range(len(data)-seq_length):
        X.append(data.iloc[i:i+seq_length, :]) 
        y.append(data.iloc[i+seq_length, 3]) 
    return np.array(X), np.array(y)

seq_length = 20
num_features = 4
X,Y = create_sequences(df,seq_length)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (2565, 20, 4)
# (2565,)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Since in this model, we use time series so we can not suffle data. We dive whole data into 2 part: train set and test set without suffle.

# %%
train_size = int(len(df)*0.8)
test_size = len(df) - train_size
x_train, x_test = X[0:train_size,:], X[train_size:,:]
y_train, y_test = Y[0:train_size], Y[train_size:]

# %%
scalerX = MinMaxScaler(feature_range=(0,1))
scalerY = MinMaxScaler(feature_range = (0,1))
x_train = scalerX.fit_transform(x_train.reshape(-1,num_features * seq_length))
x_test = scalerX.transform(x_test.reshape(-1,num_features * seq_length))
y_train = scalerY.fit_transform(y_train.reshape(-1,1))
y_test = scalerY.transform(y_test.reshape(-1,1))

# %%
x_train = x_train.reshape(-1,seq_length,num_features)
x_test = x_test.reshape(-1,seq_length, num_features)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (2068, 20, 4)
# (2068, 1)

# %% [markdown]
# ## Visualization

# %%
plt.plot(y_train)
plt.show()

# %% [markdown]
# ## Grid search

# %%
def create_model(neurons, optimizer):
 # create model
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(seq_length,4), activation = 'relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizer)

    return model

# %%
optimizer = ['GDA','Nadam']
neurons = [100,500,1000,2000]
param_grid = dict(model__neurons=neurons, model__optimizer = optimizer)

model = KerasRegressor(model=create_model, epochs=10, batch_size=5, verbose=1)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(x_train, y_train)

# %%
best_params = grid.best_params_
best_model = create_model(neurons=best_params['model__neurons'], optimizer=best_params['model__optimizer'])
best_model.fit(x_train, y_train, epochs=20, batch_size=32, verbose=0)
y_pred = best_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
# Out:
# Epoch 1/10
# 65/65 [==============================] - 16s 223ms/step - loss: 0.0065
# Epoch 2/10
# 65/65 [==============================] - 14s 222ms/step - loss: 2.3028e-04
# Epoch 3/10
# 65/65 [==============================] - 15s 228ms/step - loss: 2.2612e-04
# Epoch 4/10
# 65/65 [==============================] - 15s 223ms/step - loss: 2.3561e-04
# Epoch 5/10
# 65/65 [==============================] - 15s 228ms/step - loss: 2.3466e-04
# Epoch 6/10
# 65/65 [==============================] - 15s 230ms/step - loss: 2.2816e-04
# Epoch 7/10
# 65/65 [==============================] - 15s 228ms/step - loss: 2.0556e-04
# Epoch 8/10
# 65/65 [==============================] - 17s 256ms/step - loss: 2.0155e-04
# Epoch 9/10
# 65/65 [==============================] - 17s 258ms/step - loss: 2.0112e-04
# Epoch 10/10
# 65/65 [==============================] - 16s 251ms/step - loss: 1.8541e-04
# 16/16 [==============================] - 2s 89ms/step

# %%
plt.title("LSTM model")
plt.xlabel("Day")
plt.ylabel("Close Price ($)")
plt.plot(y_test[0:], label = "Test Target")
plt.plot(y_pred[0:], label = "Predict Target")
plt.legend()
plt.show()

# %%
plt.title("LSTM model")
plt.xlabel("Day")
plt.ylabel("Close Price ($)")
plt.plot(y_test[0:], label = "Test Target")
plt.plot(y_pred[0:], label = "Predict Target")
plt.legend()
plt.show()

# %% [markdown]
# Actually in this case, when we run more complex model, we have more smooth model and the mean square error decrease but not significantly. All of these models convergence to an similar shape with a tiny difference about degree of smoothness. Running all of this grid search is time-consuming without a big improvement so we choose a not complex model to analyze and get insight from this family of models.

# %% [markdown]
# ## Create model

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(100, input_shape=(seq_length, num_features), activation = 'relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs= 10, batch_size=32, verbose=2)
# Out:
# Epoch 1/10
# 65/65 - 1s - loss: 0.0150 - 957ms/epoch - 15ms/step
# Epoch 2/10
# 65/65 - 0s - loss: 2.2422e-04 - 351ms/epoch - 5ms/step
# Epoch 3/10
# 65/65 - 0s - loss: 1.9973e-04 - 345ms/epoch - 5ms/step
# Epoch 4/10
# 65/65 - 0s - loss: 1.9343e-04 - 347ms/epoch - 5ms/step
# Epoch 5/10
# 65/65 - 0s - loss: 1.8754e-04 - 344ms/epoch - 5ms/step
# Epoch 6/10
# 65/65 - 0s - loss: 1.8662e-04 - 339ms/epoch - 5ms/step
# Epoch 7/10
# 65/65 - 0s - loss: 1.8106e-04 - 342ms/epoch - 5ms/step
# Epoch 8/10
# 65/65 - 0s - loss: 1.8870e-04 - 337ms/epoch - 5ms/step
# Epoch 9/10
# 65/65 - 0s - loss: 1.7190e-04 - 342ms/epoch - 5ms/step
# Epoch 10/10
# 65/65 - 0s - loss: 1.6942e-04 - 342ms/epoch - 5ms/step

# %%
x_train.shape
# Out:
# (2068, 20, 4)

# %%
# make predictions
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)
print(testPredict)
# invert predictions
trainPredict = scalerY.inverse_transform(trainPredict.reshape(-1,1))
trainY = scalerY.inverse_transform(y_train.reshape(-1,1))
testPredict = scalerY.inverse_transform(testPredict.reshape(-1,1))
testY = scalerY.inverse_transform(y_test.reshape(-1,1))
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 65/65 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# [[0.9115756 ]
#  [0.9113502 ]
#  [0.9098219 ]
#  [0.9065291 ]
#  [0.90035254]
#  [0.899826  ]
#  [0.90107644]
#  [0.90165263]
#  [0.89856154]
#  [0.8968486 ]
#  [0.89174604]
#  [0.8904607 ]
#  [0.8947649 ]
#  [0.8970979 ]
#  [0.90151423]
#  [0.90880305]
#  [0.9157794 ]
#  [0.922057  ]
#  [0.9237434 ]
#  [0.9258047 ]
#  [0.9277356 ]
#  [0.92833936]
#  [0.9315055 ]
#  [0.93383837]
#  [0.9338303 ]
#  [0.9342764 ]
#  [0.934223  ]
#  [0.93050265]
#  [0.9300202 ]
#  [0.9297176 ]
#  [0.9314176 ]
#  [0.9354871 ]
#  [0.93902534]
#  [0.9435018 ]
#  [0.9483977 ]
#  [0.95178753]
#  [0.95611835]
#  [0.95957667]
#  [0.9619269 ]
#  [0.9636012 ]
#  [0.9638169 ]
#  [0.9627904 ]
#  [0.9602193 ]
#  [0.9603355 ]
#  [0.959058  ]
#  [0.9579162 ]
#  [0.9524876 ]
#  [0.9477046 ]
#  [0.94369984]
#  [0.9385978 ]
#  [0.9380077 ]
#  [0.9355194 ]
#  [0.93551654]
#  [0.9359227 ]
#  [0.9392777 ]
#  [0.9462741 ]
#  [0.95320666]
#  [0.9564915 ]
#  [0.960507  ]
#  [0.96478134]
#  [0.9678187 ]
#  [0.97037274]
#  [0.97426933]
#  [0.97626776]
#  [0.97745883]
#  [0.97801787]
#  [0.9812313 ]
#  [0.9851044 ]
#  [0.9890514 ]
#  [0.99062437]
#  [0.9891022 ]
#  [0.98841155]
#  [0.9883966 ]
#  [0.9876165 ]
#  [0.9902947 ]
#  [0.99387985]
#  [0.9986555 ]
#  [1.001876  ]
#  [1.0041354 ]
#  [1.0026925 ]
#  [1.0009474 ]
#  [1.0000439 ]
#  [0.99739957]
#  [0.9980886 ]
#  [0.99950993]
#  [1.0023617 ]
#  [1.0059426 ]
#  [1.0079323 ]
#  [1.0092179 ]
#  [1.0113401 ]
#  [1.0162089 ]
#  [1.0209485 ]
#  [1.0255324 ]
#  [1.0287715 ]
#  [1.0304636 ]
#  [1.0311183 ]
#  [1.0305976 ]
#  [1.0293158 ]
#  [1.026816  ]
#  [1.0262618 ]
#  [1.025575  ]
#  [1.0001705 ]
#  [1.0053893 ]
#  [1.0093945 ]
#  [1.0142567 ]
#  [1.0181803 ]
#  [1.0199865 ]
#  [1.0216877 ]
#  [1.0238004 ]
#  [1.027467  ]
#  [1.0303675 ]
#  [1.0331184 ]
#  [1.0350676 ]
#  [1.0355874 ]
#  [1.0361209 ]
#  [1.039247  ]
#  [1.0430584 ]
#  [1.0449156 ]
#  [1.0470535 ]
#  [1.0506042 ]
#  [1.0524521 ]
#  [1.0541841 ]
#  [1.0519713 ]
#  [1.0533062 ]
#  [1.05157   ]
#  [1.0467325 ]
#  [1.0411104 ]
#  [1.0336349 ]
#  [1.0286897 ]
#  [1.0190269 ]
#  [1.0127034 ]
#  [1.0085511 ]
#  [1.0108163 ]
#  [1.0118885 ]
#  [1.0094697 ]
#  [1.0104396 ]
#  [1.0106158 ]
#  [1.0061276 ]
#  [1.0033861 ]
#  [0.99970293]
#  [0.9913716 ]
#  [0.9860297 ]
#  [0.9778405 ]
#  [0.9697593 ]
#  [0.968785  ]
#  [0.97377807]
#  [0.98031074]
#  [0.98924094]
#  [0.9991437 ]
#  [1.0071656 ]
#  [1.0116197 ]
#  [1.0159683 ]
#  [1.0190164 ]
#  [1.0219101 ]
#  [1.0273346 ]
#  [1.0324882 ]
#  [1.0398225 ]
#  [1.0462785 ]
#  [1.0507575 ]
#  [1.0519661 ]
#  [1.0511941 ]
#  [1.0507954 ]
#  [1.0525678 ]
#  [1.0582454 ]
#  [1.062267  ]
#  [1.067953  ]
#  [1.0720453 ]
#  [1.0742242 ]
#  [1.0750792 ]
#  [1.0787432 ]
#  [1.0821005 ]
#  [1.0860839 ]
#  [1.0900826 ]
#  [1.0922979 ]
#  [1.0921506 ]
#  [1.0904168 ]
#  [1.0902513 ]
#  [1.0887698 ]
#  [1.0898045 ]
#  [1.0921154 ]
#  [1.0941322 ]
#  [1.0968856 ]
#  [1.0993463 ]
#  [1.099272  ]
#  [1.0971957 ]
#  [1.092465  ]
#  [1.0826772 ]
#  [1.0655992 ]
#  [1.052306  ]
#  [1.0419856 ]
#  [1.0420262 ]
#  [1.0434666 ]
#  [1.0404991 ]
#  [1.0399865 ]
#  [1.0345697 ]
#  [1.0262117 ]
#  [1.0250462 ]
#  [1.0306293 ]
#  [1.0337228 ]
#  [1.0377606 ]
#  [1.0410529 ]
#  [1.0371855 ]
#  [1.0318753 ]
#  [1.0302033 ]
#  [1.0271972 ]
#  [1.031985  ]
#  [1.0374447 ]
#  [1.0378305 ]
#  [1.0418984 ]
#  [1.0501844 ]
#  [1.057552  ]
#  [1.0635653 ]
#  [1.0669323 ]
#  [1.071824  ]
#  [1.0783354 ]
#  [1.0834538 ]
#  [1.0857089 ]
#  [1.0879079 ]
#  [1.0893055 ]
#  [1.0920547 ]
#  [1.0927147 ]
#  [1.0912786 ]
#  [1.0899665 ]
#  [1.086967  ]
#  [1.0856503 ]
#  [1.0835038 ]
#  [1.0822216 ]
#  [1.0803149 ]
#  [1.0694165 ]
#  [1.0588197 ]
#  [1.0575291 ]
#  [1.0584179 ]
#  [1.0539498 ]
#  [1.0517303 ]
#  [1.0520139 ]
#  [1.0585059 ]
#  [1.0627631 ]
#  [1.068453  ]
#  [1.073141  ]
#  [1.0780423 ]
#  [1.0805385 ]
#  [1.0839201 ]
#  [1.087004  ]
#  [1.0884095 ]
#  [1.0914475 ]
#  [1.0939692 ]
#  [1.0990126 ]
#  [1.1031929 ]
#  [1.1067098 ]
#  [1.1093096 ]
#  [1.1137731 ]
#  [1.1199716 ]
#  [1.1246663 ]
#  [1.1278092 ]
#  [1.132041  ]
#  [1.1349221 ]
#  [1.1368539 ]
#  [1.1396021 ]
#  [1.141133  ]
#  [1.1428999 ]
#  [1.147072  ]
#  [1.1510316 ]
#  [1.15459   ]
#  [1.1554474 ]
#  [1.15543   ]
#  [1.1561329 ]
#  [1.1590146 ]
#  [1.1626805 ]
#  [1.1670548 ]
#  [1.1699562 ]
#  [1.1701154 ]
#  [1.1633216 ]
#  [1.1619319 ]
#  [1.1619226 ]
#  [1.1659821 ]
#  [1.1686877 ]
#  [1.1695782 ]
#  [1.1710061 ]
#  [1.1745621 ]
#  [1.178882  ]
#  [1.1848471 ]
#  [1.1902794 ]
#  [1.1945645 ]
#  [1.1984504 ]
#  [1.2045058 ]
#  [1.2096925 ]
#  [1.213643  ]
#  [1.2178968 ]
#  [1.2224921 ]
#  [1.2244468 ]
#  [1.2246274 ]
#  [1.2286531 ]
#  [1.2293566 ]
#  [1.2294554 ]
#  [1.2311443 ]
#  [1.23351   ]
#  [1.2381135 ]
#  [1.2422796 ]
#  [1.2461252 ]
#  [1.2501032 ]
#  [1.2534593 ]
#  [1.2589277 ]
#  [1.2653304 ]
#  [1.2700001 ]
#  [1.2743763 ]
#  [1.2763661 ]
#  [1.277301  ]
#  [1.2674426 ]
#  [1.2634116 ]
#  [1.2631521 ]
#  [1.2603254 ]
#  [1.2564946 ]
#  [1.251919  ]
#  [1.2556806 ]
#  [1.2634903 ]
#  [1.2714761 ]
#  [1.276074  ]
#  [1.2798162 ]
#  [1.2867416 ]
#  [1.2935787 ]
#  [1.2985035 ]
#  [1.3029593 ]
#  [1.305443  ]
#  [1.3095682 ]
#  [1.3109938 ]
#  [1.3085803 ]
#  [1.289996  ]
#  [1.2679902 ]
#  [1.2424983 ]
#  [1.207431  ]
#  [1.1628869 ]
#  [1.1460699 ]
#  [1.1402298 ]
#  [1.1389433 ]
#  [1.134147  ]
#  [1.115532  ]
#  [1.0796161 ]
#  [1.0550991 ]
#  [1.0302705 ]
#  [0.9790501 ]
#  [0.94726044]
#  [0.90159017]
#  [0.8671636 ]
#  [0.83222264]
#  [0.8069121 ]
#  [0.7858956 ]
#  [0.752785  ]
#  [0.7485766 ]
#  [0.75900215]
#  [0.77939844]
#  [0.7951763 ]
#  [0.81125456]
#  [0.82534343]
#  [0.81939334]
#  [0.81509256]
#  [0.8135913 ]
#  [0.82835454]
#  [0.8499797 ]
#  [0.8676607 ]]
# Train Score: 25.62 RMSE
# Test Score: 71.44 RMSE

# %%
plt.title("LSTM model")
plt.xlabel("Day")
plt.ylabel("Close Price ($)")
plt.plot(trainY[0:100], label = "Train Target")
plt.plot(trainPredict[0:100], label = "Predict Target")
plt.legend()
plt.show()

# %%
plt.title("LSTM model")
plt.xlabel("Day")
plt.ylabel("Close Price ($)")
plt.plot(testY[0:100], label = "Test Target")
plt.plot(testPredict[0:100], label = "Predict Target")
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score
r2_test = r2_score(testY, testPredict)
r2_train = r2_score(trainY, trainPredict)
print("R-squared on train set:", r2_train)
print("R-squared on test set:", r2_test)
# Out:
# R-squared on train set: 0.9969656480442792
# R-squared on test set: 0.8762134726855786

# %% [markdown]
# ## Test for other stock without training

# %%
df_test = yf.download("IBM", start="2018-01-01", end="2020-04-10")
df_test.reset_index(drop = True, inplace = True)
#Drop columns
df_test.drop(["Adj Close", "Volume"], axis = 1, inplace = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_test
# Out:
#            Open        High         Low       Close
# 0    147.705551  148.001907  146.787766  147.466537
# 1    150.420654  152.782028  149.455063  151.520081
# 2    152.629059  155.181641  152.361374  154.588913
# 3    155.296371  155.736145  154.015289  155.344162
# 4    155.506699  156.701721  154.588913  156.281067
# ..          ...         ...         ...         ...
# 567  104.130020  105.229446  100.305923  101.663483
# 568  105.497131  110.544930  105.286804  109.770554
# 569  113.575523  114.311661  109.818359  109.885277
# 570  111.195030  114.684509  110.009560  114.043976
# 571  115.181641  117.514343  114.885277  116.156792
#
# [572 rows x 4 columns]

# %%
otherX,otherY = create_sequences(df,seq_length)
print(otherX.shape)
print(otherY.shape)
# Out:
# (2565, 20, 4)
# (2565,)

# %%
otherx_test = scalerX.transform(otherX.reshape(-1,num_features * seq_length))
othery_test = scalerY.transform(otherY.reshape(-1,1))

# %%
otherx_test = otherx_test.reshape(-1,seq_length, num_features)
print(otherx_test.shape)
# Out:
# (2565, 20, 4)

# %%
otherPredict = model.predict(otherx_test)
# Out:
# 81/81 [==============================] - 0s 2ms/step

# %%
plt.title("LSTM model on IBM")
plt.xlabel("Day")
plt.ylabel("Close Price ($)")
plt.plot(othery_test[0:200], label = "Test Target")
plt.plot(otherPredict[0:200], label = "Predict Target")
plt.legend()
plt.show()

# %%
other_r2_test = r2_score(othery_test, otherPredict)
print(other_r2_test)
# Out:
# 0.9958550409107935

# %% [markdown]
# As we can see, without training phase, our model can predict other stock price of IBM which fluatuate differently as well as S&P500

# %% [markdown]
# ## Using RNN model

# %%
# create and fit the LSTM network
RNNmodel = Sequential()
RNNmodel.add(LSTM(50, input_shape=(seq_length, num_features), activation = 'relu'))
RNNmodel.add(Dense(1))
RNNmodel.compile(loss='mean_squared_error', optimizer='adam')
RNNmodel.fit(x_train, y_train, epochs= 10, batch_size=32, verbose=2)
# Out:
# Epoch 1/10
# 65/65 - 1s - loss: 0.0471 - 727ms/epoch - 11ms/step
# Epoch 2/10
# 65/65 - 0s - loss: 3.2500e-04 - 184ms/epoch - 3ms/step
# Epoch 3/10
# 65/65 - 0s - loss: 2.2736e-04 - 184ms/epoch - 3ms/step
# Epoch 4/10
# 65/65 - 0s - loss: 2.0146e-04 - 182ms/epoch - 3ms/step
# Epoch 5/10
# 65/65 - 0s - loss: 1.9470e-04 - 184ms/epoch - 3ms/step
# Epoch 6/10
# 65/65 - 0s - loss: 1.8829e-04 - 178ms/epoch - 3ms/step
# Epoch 7/10
# 65/65 - 0s - loss: 1.7946e-04 - 187ms/epoch - 3ms/step
# Epoch 8/10
# 65/65 - 0s - loss: 1.8429e-04 - 184ms/epoch - 3ms/step
# Epoch 9/10
# 65/65 - 0s - loss: 1.9553e-04 - 184ms/epoch - 3ms/step
# Epoch 10/10
# 65/65 - 0s - loss: 1.6996e-04 - 183ms/epoch - 3ms/step

# %%
# make predictions
RNNtrainPredict = model.predict(x_train)
RNNtestPredict = model.predict(x_test)
print(testPredict)
# invert predictions
RNNtrainPredict = scalerY.inverse_transform(RNNtrainPredict.reshape(-1,1))
RNNtrainY = scalerY.inverse_transform(y_train.reshape(-1,1))
RNNtestPredict = scalerY.inverse_transform(RNNtestPredict.reshape(-1,1))
RNNtestY = scalerY.inverse_transform(y_test.reshape(-1,1))
# calculate root mean squared error
RNNtrainScore = np.sqrt(mean_squared_error(RNNtrainY, RNNtrainPredict))
print('Train Score: %.2f RMSE' % (RNNtrainScore))
RNNtestScore = np.sqrt(mean_squared_error(RNNtestY, RNNtestPredict))
print('Test Score: %.2f RMSE' % (RNNtestScore))
# Out:
# 65/65 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# [[2709.2595]
#  [2708.8423]
#  [2706.0146]
#  [2699.9219]
#  [2688.4934]
#  [2687.5193]
#  [2689.8328]
#  [2690.899 ]
#  [2685.1797]
#  [2682.0103]
#  [2672.5688]
#  [2670.1907]
#  [2678.1545]
#  [2682.4714]
#  [2690.643 ]
#  [2704.1294]
#  [2717.0376]
#  [2728.653 ]
#  [2731.7734]
#  [2735.5874]
#  [2739.1602]
#  [2740.277 ]
#  [2746.1355]
#  [2750.452 ]
#  [2750.437 ]
#  [2751.2625]
#  [2751.1636]
#  [2744.2798]
#  [2743.3872]
#  [2742.8274]
#  [2745.9727]
#  [2753.5027]
#  [2760.0493]
#  [2768.332 ]
#  [2777.3909]
#  [2783.663 ]
#  [2791.6763]
#  [2798.0752]
#  [2802.4238]
#  [2805.5217]
#  [2805.921 ]
#  [2804.0217]
#  [2799.2644]
#  [2799.4792]
#  [2797.1155]
#  [2795.003 ]
#  [2784.9583]
#  [2776.1086]
#  [2768.6985]
#  [2759.2583]
#  [2758.1663]
#  [2753.5623]
#  [2753.5571]
#  [2754.3086]
#  [2760.5164]
#  [2773.4617]
#  [2786.2888]
#  [2792.3667]
#  [2799.7966]
#  [2807.7056]
#  [2813.3254]
#  [2818.0513]
#  [2825.261 ]
#  [2828.9587]
#  [2831.1624]
#  [2832.1968]
#  [2838.1426]
#  [2845.309 ]
#  [2852.612 ]
#  [2855.5225]
#  [2852.706 ]
#  [2851.428 ]
#  [2851.4004]
#  [2849.957 ]
#  [2854.9124]
#  [2861.5461]
#  [2870.3826]
#  [2876.3413]
#  [2880.5217]
#  [2877.8518]
#  [2874.623 ]
#  [3036.4534]
#  [3042.0745]
#  [3046.7405]
#  [3056.072 ]
#  [3063.807 ]
#  [3070.3142]
#  [3075.1245]
#  [3083.3833]
#  [3094.8523]
#  [3103.539 ]
#  [3109.354 ]
#  [3117.184 ]
#  [3122.5151]
#  [3126.0896]
#  [3131.1743]
#  [3134.007 ]
#  [3137.2764]
#  [3144.9958]
#  [3152.3223]
#  [3158.9065]
#  [3160.493 ]
#  [3160.4607]
#  [3161.7612]
#  [3167.0933]
#  [3173.8762]
#  [3181.97  ]
#  [3187.3384]
#  [3187.6328]
#  [3175.0625]
#  [3172.491 ]
#  [3172.4739]
#  [3179.985 ]
#  [3184.9912]
#  [3186.639 ]
#  [3189.281 ]
#  [3195.8606]
#  [3203.8538]
#  [3214.8909]
#  [3224.9421]
#  [3232.8708]
#  [3240.061 ]
#  [3251.2651]
#  [3260.862 ]
#  [3268.1716]
#  [3276.0425]
#  [3284.545 ]
#  [3288.1616]
#  [3288.4958]
#  [3295.9446]
#  [3297.2463]
#  [3297.429 ]
#  [3300.5542]
#  [3304.9314]
#  [3313.4492]
#  [3321.1577]
#  [3328.2732]
#  [3335.6335]
#  [3341.8433]
#  [3351.9614]
#  [3363.8083]
#  [3372.4485]
#  [3380.546 ]
#  [3384.2275]
#  [3385.9573]
#  [3367.7166]
#  [3360.258 ]
#  [3359.7778]
#  [3354.5476]
#  [3347.4595]
#  [3338.9934]
#  [3345.9534]
#  [3360.4036]
#  [3375.1797]
#  [3383.6873]
#  [3390.611 ]
#  [3403.4253]
#  [3416.076 ]
#  [3425.1882]
#  [3433.4326]
#  [3438.0283]
#  [3445.661 ]
#  [3448.2988]
#  [3443.833 ]
#  [3409.4468]
#  [3368.7297]
#  [3321.5623]
#  [3256.6775]
#  [3174.258 ]
#  [3143.1418]
#  [3132.336 ]
#  [3129.9556]
#  [3121.081 ]
#  [3086.638 ]
#  [3020.1829]
#  [2974.8193]
#  [2928.8792]
#  [2834.1067]
#  [2775.2866]
#  [2690.7834]
#  [2627.0842]
#  [2562.4333]
#  [2515.6016]
#  [2476.7148]
#  [2415.4507]
#  [2407.6638]
#  [2426.9543]
#  [2464.693 ]
#  [2493.887 ]
#  [2523.6365]
#  [2549.7048]
#  [2538.6956]
#  [2530.7378]
#  [2527.96  ]
#  [2555.2764]
#  [2595.289 ]
#  [2628.0042]]
# Train Score: 25.62 RMSE
# Test Score: 71.44 RMSE

# %%
plt.title("RNN model")
plt.xlabel("Day")
plt.ylabel("Close Price ($)")
plt.plot(RNNtrainY[0:100], label = "Train Target")
plt.plot(RNNtrainPredict[0:100], label = "Predict Target")
plt.legend()
plt.show()

# %%
plt.title("RNN model")
plt.xlabel("Day")
plt.ylabel("Close Price ($)")
plt.plot(RNNtestY[0:100], label = "Test Target")
plt.plot(RNNtestPredict[0:100], label = "Predict Target")
plt.legend()
plt.show()

# %% [markdown]
# ## Test with random data

# %% [markdown]
# ###### For simplictit, we create an new model with feature of each timestep is close price of previous day

# %%
df = yf.download("^GSPC", start="2010-01-01", end="2020-04-10")
df = df["Close"]

df = df.reset_index("Date")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))
df.drop("Date", axis = 1, inplace = True)
scaledData = scaler.fit_transform(df)

# %%
def create_sequences(data, seq_length):
    print(data)
    X = []
    y = []
    for i in range(len(data)-seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)
scaledX, scaledY = create_sequences(scaledData, 20)
# Out:
# [[0.04671323]
#  [0.04820674]
#  [0.04846905]
#  ...
#  [0.69252443]
#  [0.73084362]
#  [0.74769951]]

# %%
train_size = int(len(df)*0.8)
test_size = len(df) - train_size
x_train, x_test = scaledX[0:train_size,:], scaledX[train_size:,:]
y_train, y_test = scaledY[0:train_size], scaledY[train_size:]

# %%
plt.plot(y_train)
plt.show()

# %%
seq_length = 20
x_train = np.reshape(x_train,(x_train.shape[0],seq_length,1))
x_test = np.reshape(x_test,(x_test.shape[0],seq_length,1))
print(len(x_test))
# Out:
# 497

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(seq_length,1), activation = 'relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=10, batch_size=1, verbose=2)
# Out:
# Epoch 1/10
# 2068/2068 - 4s - loss: 9.4374e-04 - 4s/epoch - 2ms/step
# Epoch 2/10
# 2068/2068 - 4s - loss: 2.3445e-04 - 4s/epoch - 2ms/step
# Epoch 3/10
# 2068/2068 - 3s - loss: 1.6445e-04 - 3s/epoch - 2ms/step
# Epoch 4/10
# 2068/2068 - 3s - loss: 1.3855e-04 - 3s/epoch - 2ms/step
# Epoch 5/10
# 2068/2068 - 6s - loss: 1.1537e-04 - 6s/epoch - 3ms/step
# Epoch 6/10
# 2068/2068 - 9s - loss: 9.6275e-05 - 9s/epoch - 4ms/step
# Epoch 7/10
# 2068/2068 - 9s - loss: 9.3533e-05 - 9s/epoch - 4ms/step
# Epoch 8/10
# 2068/2068 - 7s - loss: 8.5158e-05 - 7s/epoch - 3ms/step
# Epoch 9/10
# 2068/2068 - 8s - loss: 9.0920e-05 - 8s/epoch - 4ms/step
# Epoch 10/10
# 2068/2068 - 11s - loss: 9.2954e-05 - 11s/epoch - 5ms/step

# %%
# make predictions
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)
print(testPredict)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(y_train)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(y_test)
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 65/65 [==============================] - 1s 9ms/step
# 16/16 [==============================] - 0s 9ms/step
# [[0.7050018 ]
#  [0.69468945]
#  [0.69416064]
#  [0.6803138 ]
#  [0.6811779 ]
#  [0.693294  ]
#  [0.69588   ]
#  [0.68658257]
#  [0.68807596]
#  [0.6808919 ]
#  [0.67780775]
#  [0.6915646 ]
#  [0.69696414]
#  [0.6964784 ]
#  [0.7064548 ]
#  [0.71763456]
#  [0.7199774 ]
#  [0.72037715]
#  [0.712429  ]
#  [0.7161731 ]
#  [0.7160453 ]
#  [0.71304387]
#  [0.7210099 ]
#  [0.7184018 ]
#  [0.7214101 ]
#  [0.719463  ]
#  [0.71651024]
#  [0.70344603]
#  [0.7164628 ]
#  [0.7107844 ]
#  [0.72176945]
#  [0.7279583 ]
#  [0.7286925 ]
#  [0.737938  ]
#  [0.73773175]
#  [0.74071914]
#  [0.7420805 ]
#  [0.7440242 ]
#  [0.7394417 ]
#  [0.6284042 ]
#  [0.6034798 ]
#  [0.6332877 ]
#  [0.6452627 ]
#  [0.6554478 ]
#  [0.6598285 ]
#  [0.66417044]
#  [0.66404605]
#  [0.65822434]
#  [0.6687041 ]
#  [0.6725399 ]
#  [0.6805325 ]
#  [0.69514376]
#  [0.68077147]
#  [0.6807688 ]
#  [0.68285453]
#  [0.6923912 ]
#  [0.6848213 ]
#  [0.68198955]
#  [0.6986897 ]
#  [0.7100168 ]
#  [0.71122044]
#  [0.7179577 ]
#  [0.72356206]
#  [0.72113526]
#  [0.71003926]
#  [0.70989203]
#  [0.711384  ]
#  [0.7260831 ]
#  [0.7307967 ]
#  [0.72733897]
#  [0.73886865]
#  [0.74166864]
#  [0.74331564]
#  [0.73908556]
#  [0.7459714 ]
#  [0.7482117 ]
#  [0.7471601 ]
#  [0.7462594 ]
#  [0.7429662 ]
#  [0.75076026]
#  [0.74710655]
#  [0.74511915]
#  [0.73755753]
#  [0.72782046]
#  [0.72510946]
#  [0.7421865 ]
#  [0.74734014]
#  [0.75483817]
#  [0.7538306 ]
#  [0.75897557]
#  [0.7636493 ]
#  [0.7635361 ]
#  [0.7597125 ]
#  [0.77217096]
#  [0.75075036]
#  [0.7475363 ]
#  [0.7568072 ]
#  [0.7525823 ]
#  [0.7560068 ]
#  [0.7642979 ]
#  [0.778439  ]
#  [0.77892137]
#  [0.78052443]
#  [0.7828925 ]
#  [0.78853905]
#  [0.79004925]
#  [0.78241235]
#  [0.785978  ]
#  [0.7867482 ]
#  [0.79475564]
#  [0.7944564 ]
#  [0.7945661 ]
#  [0.7917117 ]
#  [0.79346466]
#  [0.79502124]
#  [0.80592555]
#  [0.8037823 ]
#  [0.8024936 ]
#  [0.8082055 ]
#  [0.80998963]
#  [0.8109614 ]
#  [0.80149615]
#  [0.7982446 ]
#  [0.81055063]
#  [0.80607563]
#  [0.78467566]
#  [0.78154904]
#  [0.77907825]
#  [0.7839099 ]
#  [0.7553581 ]
#  [0.76250976]
#  [0.77158076]
#  [0.782772  ]
#  [0.7758642 ]
#  [0.76641876]
#  [0.7760373 ]
#  [0.77394974]
#  [0.7591298 ]
#  [0.759668  ]
#  [0.750753  ]
#  [0.74222004]
#  [0.7445349 ]
#  [0.73010725]
#  [0.72578615]
#  [0.75053346]
#  [0.76249   ]
#  [0.76920646]
#  [0.78103405]
#  [0.7867859 ]
#  [0.7858683 ]
#  [0.7828011 ]
#  [0.7875389 ]
#  [0.7861439 ]
#  [0.7869974 ]
#  [0.7989606 ]
#  [0.8034121 ]
#  [0.81468934]
#  [0.8133642 ]
#  [0.8103475 ]
#  [0.7983032 ]
#  [0.7963232 ]
#  [0.80177927]
#  [0.80959207]
#  [0.8193671 ]
#  [0.8230545 ]
#  [0.8322157 ]
#  [0.83001053]
#  [0.82308805]
#  [0.82433766]
#  [0.8306427 ]
#  [0.83396095]
#  [0.83967537]
#  [0.83990717]
#  [0.8351249 ]
#  [0.82644635]
#  [0.83090746]
#  [0.82391876]
#  [0.82701486]
#  [0.8363176 ]
#  [0.9932337 ]
#  [0.9905012 ]
#  [0.99259657]
#  [0.98834616]
#  [0.99539286]
#  [0.98999095]
#  [0.97368544]
#  [0.9243335 ]
#  [0.88231224]
#  [0.88004327]
#  [0.8239961 ]
#  [0.8120715 ]
#  [0.8700454 ]
#  [0.8377928 ]
#  [0.8865126 ]
#  [0.8452298 ]
#  [0.8197337 ]
#  [0.72734535]
#  [0.77595145]
#  [0.7272127 ]
#  [0.6237857 ]
#  [0.6950107 ]
#  [0.5877333 ]
#  [0.625964  ]
#  [0.584594  ]
#  [0.5844873 ]
#  [0.54566336]
#  [0.51482403]
#  [0.58562106]
#  [0.6122309 ]
#  [0.67164093]
#  [0.64446723]
#  [0.67336375]
#  [0.6609172 ]
#  [0.61279476]
#  [0.6300685 ]
#  [0.6196464 ]
#  [0.6824389 ]
#  [0.6911981 ]
#  [0.72696584]]
# Train Score: 16.12 RMSE
# Test Score: 41.13 RMSE

# %%
plt.plot(testPredict[:100], label = "predict")
plt.plot(testY[:100], label = "target")
plt.legend()

# %% [markdown]
# From here we can also see that compare to four-feature model, there is not many difference

# %% [markdown]
# #### Create random data

# %%
np.random.seed(100)
data_test = np.random.random((200,1))
data_test
# Out:
# array([[0.54340494],
#        [0.27836939],
#        [0.42451759],
#        [0.84477613],
#        [0.00471886],
#        [0.12156912],
#        [0.67074908],
#        [0.82585276],
#        [0.13670659],
#        [0.57509333],
#        [0.89132195],
#        [0.20920212],
#        [0.18532822],
#        [0.10837689],
#        [0.21969749],
#        [0.97862378],
#        [0.81168315],
#        [0.17194101],
#        [0.81622475],
#        [0.27407375],
#        [0.43170418],
#        [0.94002982],
#        [0.81764938],
#        [0.33611195],
#        [0.17541045],
#        [0.37283205],
#        [0.00568851],
#        [0.25242635],
#        [0.79566251],
#        [0.01525497],
#        [0.59884338],
#        [0.60380454],
#        [0.10514769],
#        [0.38194344],
#        [0.03647606],
#        [0.89041156],
#        [0.98092086],
#        [0.05994199],
#        [0.89054594],
#        [0.5769015 ],
#        [0.74247969],
#        [0.63018394],
#        [0.58184219],
#        [0.02043913],
#        [0.21002658],
#        [0.54468488],
#        [0.76911517],
#        [0.25069523],
#        [0.28589569],
#        [0.85239509],
#        [0.97500649],
#        [0.88485329],
#        [0.35950784],
#        [0.59885895],
#        [0.35479561],
#        [0.34019022],
#        [0.17808099],
#        [0.23769421],
#        [0.04486228],
#        [0.50543143],
#        [0.37625245],
#        [0.5928054 ],
#        [0.62994188],
#        [0.14260031],
#        [0.9338413 ],
#        [0.94637988],
#        [0.60229666],
#        [0.38776628],
#        [0.363188  ],
#        [0.20434528],
#        [0.27676506],
#        [0.24653588],
#        [0.173608  ],
#        [0.96660969],
#        [0.9570126 ],
#        [0.59797368],
#        [0.73130075],
#        [0.34038522],
#        [0.0920556 ],
#        [0.46349802],
#        [0.50869889],
#        [0.08846017],
#        [0.52803522],
#        [0.99215804],
#        [0.39503593],
#        [0.33559644],
#        [0.80545054],
#        [0.75434899],
#        [0.31306644],
#        [0.63403668],
#        [0.54040458],
#        [0.29679375],
#        [0.1107879 ],
#        [0.3126403 ],
#        [0.45697913],
#        [0.65894007],
#        [0.25425752],
#        [0.64110126],
#        [0.20012361],
#        [0.65762481],
#        [0.77828922],
#        [0.7795984 ],
#        [0.61032815],
#        [0.30900035],
#        [0.69773491],
#        [0.8596183 ],
#        [0.62532376],
#        [0.98240783],
#        [0.97650013],
#        [0.16669413],
#        [0.02317814],
#        [0.16074455],
#        [0.92349683],
#        [0.95354985],
#        [0.21097842],
#        [0.36052525],
#        [0.54937526],
#        [0.27183085],
#        [0.46060162],
#        [0.69616156],
#        [0.5003559 ],
#        [0.71607099],
#        [0.52595594],
#        [0.00139902],
#        [0.39470029],
#        [0.49216697],
#        [0.40288033],
#        [0.3542983 ],
#        [0.50061432],
#        [0.44517663],
#        [0.09043279],
#        [0.27356292],
#        [0.9434771 ],
#        [0.02654464],
#        [0.03999869],
#        [0.28314036],
#        [0.58234417],
#        [0.9908928 ],
#        [0.99264224],
#        [0.99311737],
#        [0.11004833],
#        [0.66448145],
#        [0.52398683],
#        [0.17314991],
#        [0.94296024],
#        [0.24186009],
#        [0.99893227],
#        [0.58269382],
#        [0.183279  ],
#        [0.38684542],
#        [0.18967353],
#        [0.41077067],
#        [0.59468007],
#        [0.71658609],
#        [0.48689148],
#        [0.30958982],
#        [0.57744137],
#        [0.44170782],
#        [0.3596781 ],
#        [0.32133193],
#        [0.20820724],
#        [0.45125862],
#        [0.49184291],
#        [0.89907631],
#        [0.72936046],
#        [0.77008977],
#        [0.37543925],
#        [0.34373954],
#        [0.65503521],
#        [0.71103799],
#        [0.11353758],
#        [0.13302869],
#        [0.45603906],
#        [0.15973623],
#        [0.9616419 ],
#        [0.83761574],
#        [0.52016069],
#        [0.21827226],
#        [0.13491872],
#        [0.97907035],
#        [0.7070435 ],
#        [0.85997556],
#        [0.38717263],
#        [0.25083402],
#        [0.29943802],
#        [0.85689553],
#        [0.47298399],
#        [0.66327705],
#        [0.80572861],
#        [0.2529805 ],
#        [0.07957344],
#        [0.73276061],
#        [0.96139748],
#        [0.95380473],
#        [0.49049905],
#        [0.63219206],
#        [0.73299502],
#        [0.9024095 ],
#        [0.16224692],
#        [0.40588132]])

# %%
df_test = pd.DataFrame(data_test)

# %%
def create_sequences(data: pd.DataFrame, seq_length: int):
    X = []
    y = []
    for i in range(len(data)-seq_length):
        X.append(data.iloc[i:i+seq_length, :]) 
        y.append(data.iloc[i+seq_length, 0]) 
    return np.array(X), np.array(y)
X_test, Y_test = create_sequences(df_test, 20)
X_test.shape
# Out:
# (180, 20, 1)

# %%
y_pred = model.predict(X_test)
# Out:
# 6/6 [==============================] - 0s 8ms/step

# %%
testPredict = scaler.inverse_transform(y_pred)
testY = scaler.inverse_transform(Y_test.reshape(-1,1))

# %%
plt.plot(Y_test[0:50], label = 'Target')
plt.plot(y_pred[0:50], label = 'Predict')
plt.legend()

# %% [markdown]
# ###### Shift 1 day

# %%
plt.plot(Y_test[0:49], label = 'Target')
plt.plot(y_pred[1:50], label = 'Predict')
plt.legend()
